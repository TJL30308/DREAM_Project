# %% [markdown]
# # Total ER Visit by State Exploratory Analysis
# ### Observations
#
# *All states saw an incremental increase in ER visits with the exception of Tennessee

# %%
from params import states_list, years_list
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import linregress

# %%
total_er_visits = "Resources/total_er_visits.csv"
total_er_visits = pd.read_csv(total_er_visits)

# %%
total_er_df = pd.DataFrame(total_er_visits)
total_er_df = total_er_df.set_index('State')

total_er_df
# Out:
#                    2010     2011     2012     2013     2014
# State
# Arizona         2305413  2416553  2476208  2432305  2569082
# Florida         8173500  8507584  9041333  9194744  9764626
# Illinois        4955198  5140486  5305026  5092925  5245177
# Iowa            1140898  1171011  1188770  1159998  1194712
# Kentucky        2404944  2433143  2430001  2321513  2436880
# Maryland        2408759  2498178  2619227  2530131  2527936
# Minnesota       1801852  1876179  1789410  1749949  1865994
# Nebraska         536858   538245   546455   551549   563255
# North Carolina  4125701  5633259  4499568  4585990  4672977
# South Carolina  2169044  2231509  2283494  2322938  2391435
# Tennessee       3049512  3125889  2981011  2921177  2755526
# Vermont          263222   266996   272781   267490   262080

# %%
ax = total_er_df.plot.bar(figsize = (10, 3))
ax.set_title("ER Visits by State")
ax.set_ylabel("Total Visits")
ax.grid()

# %%
plt.bar(total_er_df['State'], 
        total_er_df['2010'])

plt.xticks(rotation = 45 )
plt.title('Total Number of ER Visits (2010)')
plt.xlabel('Total Number of Visits')
plt.ylabel('State')
plt.grid()

# %%
plt.bar(total_er_df['State'], 
        total_er_df['2011'])

plt.xticks(rotation = 45 )
plt.title('Total Number of ER Visits (2011)')
plt.xlabel('Total Number of Visits')
plt.ylabel('State')
plt.grid()

# %%
plt.bar(total_er_df['State'], 
        total_er_df['2012'])

plt.xticks(rotation = 45 )
plt.title('Total Number of ER Visits (2012)')
plt.xlabel('Total Number of Visits')
plt.ylabel('State')
plt.grid()

# %%
plt.bar(total_er_df['State'], 
        total_er_df['2013'])

plt.xticks(rotation = 45 )
plt.title('Total Number of ER Visits (2013)')
plt.xlabel('Total Number of Visits')
plt.ylabel('State')
plt.grid()

# %%
plt.bar(total_er_df['State'], 
        total_er_df['2014'])

plt.xticks(rotation = 45 )
plt.title('Total Number of ER Visits (2014)')
plt.xlabel('Total Number of Visits')
plt.ylabel('State')
plt.grid()

# %%
total_er_df.iloc[0].plot(y='2010')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-53768d07476f> in <module>
# ----> 1 total_er_df.iloc[0].plot(y='2010')
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
# ...
