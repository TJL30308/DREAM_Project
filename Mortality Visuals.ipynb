# %%
from params import states_list, years_list
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mortality_df = pd.read_csv('Resources/crudemortality.csv')

# %%
mortality_df
# Out:
#              STATE   2010   2011   2012   2013    2014
# 0          Arizona  731.6  747.4  755.8  761.6   765.6
# 1          Florida  924.4  910.5  916.0  924.0   934.8
# 2         Illinois  778.8  792.5  795.7  802.1   817.5
# 3             Iowa  910.8  919.6  922.9  936.1   939.5
# 4         Kentucky  967.5  975.4  996.1  994.6  1015.9
# 5         Maryland  750.4  748.6  754.9  769.3   767.5
# 6        Minnesota  734.8  744.6  743.7  755.9   759.5
# 7         Nebraska  830.7  840.1  843.9  842.9   849.2
# 8   North Carolina  826.1  827.7  840.4  846.1   858.5
# 9   South Carolina  899.7  900.3  914.7  934.3   940.6
# 10       Tennessee  938.8  946.2  959.8  975.9   987.3
# 11         Vermont  859.8  867.3  877.0  899.6   897.4

# %%
plt.plot(mortality_df['STATE'], mortality_df['2010'], mortality_df['STATE'], mortality_df['2011'], mortality_df['STATE'],mortality_df['2012'], mortality_df['STATE'],mortality_df['2013'], mortality_df['STATE'],mortality_df['2014'])
# plt.legend(loc = 'best', handles = mortality_df['STATE'])
plt.xlabel('State')
plt.ylabel('Deaths per 100,000')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.bar(mortality_df['STATE'],mortality_df['2010'])
plt.xlabel('State')
plt.ylabel('Deaths per 100,000')
plt.xticks(rotation = 45)
plt.show()

# %%
ax = mortality_df.plot.bar(figsize=(10,10), colormap = 'Paired')
ax.set_title('Mortality Rates')
ax.set_ylabel('Deaths per 100,000')
plt.legend(loc = 'best')
ax.grid()

# %%
mortality_df / 1000
# Out:
#                   2010    2011    2012    2013    2014
# STATE
# Arizona         0.7316  0.7474  0.7558  0.7616  0.7656
# Florida         0.9244  0.9105  0.9160  0.9240  0.9348
# Illinois        0.7788  0.7925  0.7957  0.8021  0.8175
# Iowa            0.9108  0.9196  0.9229  0.9361  0.9395
# Kentucky        0.9675  0.9754  0.9961  0.9946  1.0159
# Maryland        0.7504  0.7486  0.7549  0.7693  0.7675
# Minnesota       0.7348  0.7446  0.7437  0.7559  0.7595
# Nebraska        0.8307  0.8401  0.8439  0.8429  0.8492
# North Carolina  0.8261  0.8277  0.8404  0.8461  0.8585
# South Carolina  0.8997  0.9003  0.9147  0.9343  0.9406
# Tennessee       0.9388  0.9462  0.9598  0.9759  0.9873
# Vermont         0.8598  0.8673  0.8770  0.8996  0.8974
